-- %% [markdown]
-- # [dbo].[b_virtual]

-- %%
USE [Sapucai]
GO

-- %%
/****** Object:  Table [dbo].[b_virtual]    Script Date: 13/11/2023 16:59:28 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[b_virtual](
	[ID_BV] [int] IDENTITY(1,1) NOT NULL,
	[moneda] [nchar](10) NULL,
	[saldo] [decimal](18, 0) NULL,
	[moneda_adquirida] [nchar](10) NULL,
	[saldo_adquirido] [decimal](18, 0) NULL,
 CONSTRAINT [PK_b_virtual] PRIMARY KEY CLUSTERED 
(
	[ID_BV] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[token]

-- %%
/****** Object:  Table [dbo].[token]    Script Date: 13/11/2023 16:59:28 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[token](
	[ID_token] [int] NULL,
	[tiempo_vencimiento] [timestamp] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[transacciones]

-- %%
/****** Object:  Table [dbo].[transacciones]    Script Date: 13/11/2023 16:59:28 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[transacciones](
	[ID_TRANS] [int] IDENTITY(1,1) NOT NULL,
	[usuarioemisor] [int] NULL,
	[usuarioreceptor] [int] NULL,
	[monto] [decimal](18, 0) NULL,
	[fechahora] [timestamp] NULL,
 CONSTRAINT [PK_transacciones] PRIMARY KEY CLUSTERED 
(
	[ID_TRANS] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuario]

-- %%
/****** Object:  Table [dbo].[Usuario]    Script Date: 13/11/2023 16:59:28 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuario](
	[ID_Usuario] [int] IDENTITY(1,1) NOT NULL,
	[Nombre] [varchar](50) NULL,
	[Email] [varchar](50) NULL,
	[Password] [varchar](50) NULL
) ON [PRIMARY]
GO
